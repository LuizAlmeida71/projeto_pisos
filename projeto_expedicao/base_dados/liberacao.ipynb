# %%
# 0. Importação de pacotes
import pandas as pd 
import numpy as np 
from ydata_profiling import ProfileReport 
import os

# %%
# 1. Importação de base de dados 
try:
    base_166 = pd.read_excel(r'166_agosto25_1ano.xlsx')
    base_741 = pd.read_excel(r'160741_agosto25_1ano.xlsx')
    print(f'✅Bases de dados importadas com sucesso')
except FileNotFoundError as e:
    print(f'❌ERRO: Problemas ao importar bases de dados. Verificar em: {e}')
# Out:
# ✅Bases de dados importadas com sucesso

# %%
# 2. Conhecendo as bases de dados
# 2.1. Base 166

base_166_pendente = base_166[base_166['produto_retirar_saldos_view_qtdsaldo'] > 0]
print(f'🔍A base tem {len(base_166_pendente)} linhas e composta das seguintes colunas: {base_166.info()}\n A soma das quantidades pendentes é: {base_166_pendente['produto_retirar_saldos_view_qtdsaldo'].sum()}')
base_166_pendente.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3320 entries, 0 to 3319
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   produto_retirar_dtmovimento           3320 non-null   datetime64[ns]
#  1   produto_retirar_idlocalretirada       3320 non-null   int64
#  2   produto_retirar_dtpreventrega         3320 non-null   object
#  3   local_retirada_descrlocalretirada     3320 non-null   object
#  4   produtos_view_idsubproduto            3320 non-null   int64
#  5   produtos_view_descricaoproduto        3320 non-null   object
#  6   Número Nota                           3320 non-null   int64
#  7   notas_serienota                       3320 non-null   object
#  8   Local Retirada                        3320 non-null   int64
#  9   Descrição do Local                    3320 non-null   object
#  10  produto_retirar_saldos_view_qtdsaldo  3320 non-null   float64
# ...

# %%
# 2.2. Base 741 

base_741_pendente = base_741[base_741['situacao'] == 'Pendente']
print(f'🔍A base tem {len(base_741_pendente)} linhas e composta das seguintes colunas: {base_741.info()}\n A soma das quantidades pendentes é: {base_741_pendente['saldo'].sum()}')
base_741_pendente.head()

# buscar um chave primaria usando idsubproduto
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95966 entries, 0 to 95965
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   idempresa           95966 non-null  int64
#  1   razaosocial         95966 non-null  object
#  2   idplanilha          95966 non-null  int64
#  3   idproduto           95966 non-null  int64
#  4   idsubproduto        95966 non-null  int64
#  5   descricao           95966 non-null  object
#  6   idorcamento         95966 non-null  int64
#  7   dtmovimento         95966 non-null  object
#  8   idclifor            95966 non-null  int64
#  9   nomecliente         95966 non-null  object
#  10  qtdproduto          95966 non-null  float64
#  11  qtdentregue         95966 non-null  float64
#  12  valunitliquido      95966 non-null  float64
#  13  valtotliquido       95966 non-null  float64
#  14  qtddevcomreentrega  95966 non-null  float64
# ...
